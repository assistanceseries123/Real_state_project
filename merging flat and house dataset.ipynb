# %%
import numpy as np
import pandas as pd

# %%
flats=pd.read_csv('flats_cleaned.csv')
houses=pd.read_csv('house_cleaned.csv')

# %%
df=pd.concat([flats,houses],ignore_index=True)

# %%
df=df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type
# 0                2 BHK Flat in Sector 85 Gurgaon          flat  \
# 1        5 Bedroom House for sale in DLF Phase 2           NaN
# 2  5 Bedroom House for sale in Sector 66 Gurgaon           NaN
# 3                  3 BHK Flat in Nirvana Country          flat
# 4               3 BHK Flat in Sector 102 Gurgaon          flat
#
#                    society  price  price_per_sqft    area
# 0              ss the leaf   1.15         10017.0  1148.0  \
# 1                      nul   6.25         34722.0  1800.0
# 2       emaar mgf marbella    NaN             NaN     NaN
# 3          the close north   2.50         11944.0  2093.0
# 4  adani m2k oyster grande   1.90          9105.0  2087.0
#
#                                         areaWithType  bedRoom  bathroom
# 0  Super Built up area 1640(152.36 sq.m.)Carpet a...        2         2  \
# 1                        Plot area 200(167.23 sq.m.)        5         5
# 2                        Plot area 350(292.64 sq.m.)        5         5
# 3             Super Built up area 2093(194.45 sq.m.)        3         3
# 4             Super Built up area 1889(175.49 sq.m.)        3         4
#
#   balcony  ...                                        address floorNum
# 0      3+  ...  Tower-T1, Sector 85 Gurgaon, Gurgaon, Haryana     18.0  \
# 1       3  ...                  DLF Phase 2, Gurgaon, Haryana      2.0
# 2      3+  ...       14a, Sector 66 Gurgaon, Gurgaon, Haryana      3.0
# 3       3  ...         111, Nirvana Country, Gurgaon, Haryana     11.0
# 4       3  ...           Sector 102 Gurgaon, Gurgaon, Haryana      8.0
#
#        facing     agePossession
# 0        East   1 to 5 Year Old  \
# 1        East  5 to 10 Year Old
# 2        East   1 to 5 Year Old
# 3  North-East   1 to 5 Year Old
# 4  North-East   1 to 5 Year Old
#
#                                      nearbyLocations
# 0  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...  \
# 1  ['Vodafone belvedere towers metro station', 'D...
# 2  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 3  ['Sector 55-56 Metro Station', 'Eros City Squa...
# 4  ['WTC Plaza', 'Star Mall', 'Dwarka Expy, Dhanw...
#
#                                          description
# 0  This 2 bhk apartment is available for sale in ...  \
# 1  It's an beautiful 5bhk villa at very prime loc...
# 2  Excellent location, 24 meter wide road facing ...
# 3  3 bhk apartment for sale in the close north, a...
# 4  Looking for a 3 bhk property for sale in gurga...
#
#                                       furnishDetails
# 0  ['10 Light', '4 AC', 'No Bed', 'No Chimney', '...  \
# 1  ['5 Wardrobe', '8 Fan', '1 Exhaust Fan', '5 Ge...
# 2  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '15 L...
# 3  ['3 Wardrobe', '1 Water Purifier', '5 Fan', '1...
# 4  ['7 Fan', '4 Geyser', '6 Light', '5 AC', 'No B...
#
#                                             features
# 0  ['Centrally Air Conditioned', 'Water purifier'...  \
# 1  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 2  ['Centrally Air Conditioned', 'Water purifier'...
# 3  ['Water purifier', 'Power Back-up', 'Feng Shui...
# 4  ['Water purifier', 'Security / Fire Alarm', 'F...
#
#                                               rating propert_type
# 0  ['Green Area4.5 out of 5', 'Construction4.5 ou...          NaN
# 1  ['Environment5 out of 5', 'Lifestyle5 out of 5...        house
# 2  ['Environment3 out of 5', 'Lifestyle4 out of 5...        house
# 3  ['Green Area5 out of 5', 'Construction4 out of...          NaN
# 4  ['Green Area5 out of 5', 'Construction4.5 out ...          NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (3961, 21)

# %%
df.to_csv('gurgaon_properties.csv',index=False)
